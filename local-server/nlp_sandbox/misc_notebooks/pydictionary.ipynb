# %% [markdown]
# # PythonDictionary
#
# [https://github.com/Vishnunkumar/PythonDictionary/](https://github.com/Vishnunkumar/PythonDictionary/)

# %%
import sys
# !{sys.executable} -m pip install PyDictionary
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for goslate: filename=goslate-1.5.4-py3-none-any.whl size=11628 sha256=5b2e34ac412d11407c610abdf900c0f069c4ec8f0fd5422276724145a2187d06
#   Stored in directory: /Users/austinsand/Library/Caches/pip/wheels/bc/54/a5/e2e504b0fd04ca038ae401212af643fb056eeabdcf42b16775
# ...
#   Created wheel for futures: filename=futures-3.0.5-py3-none-any.whl size=13910 sha256=6187b3df5e3a144107827f3af521cf40f1719618eec1388b4ae0fc52b09662af
#   Stored in directory: /Users/austinsand/Library/Caches/pip/wheels/4e/fb/0a/e384a2d8f43aec14d63fdd277e546431a86435354ff701f1ee
# Successfully built goslate futures
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [PyDictionary]
# ...
#
# ...

# %%
import PyDictionary

pydictionary = PyDictionary.PyDictionary(word="world")
definitions, synonyms = pydictionary.getDefinitions(partOfSpeech="noun")
audio = pydictionary.getAudio()
dictionary = pydictionary.getDictionary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import PyDictionary
# ----> 3 pydictionary = PyDictionary.PyDictionary(word="world")
#       4 definitions, synonyms = pydictionary.getDefinitions(partOfSpeech="noun")
#       5 audio = pydictionary.getAudio()
#
# TypeError: PyDictionary.__init__() got an unexpected keyword argument 'word'
